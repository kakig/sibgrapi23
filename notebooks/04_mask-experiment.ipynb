# %%
import numpy as np
from matplotlib import pyplot as plt
import cv2
import PIL

# %%
d = np.load('../data/01_raw/masks/1002.npz')

# %%
m = d['masks'][np.argmax(d['scores'])]
m
# Out:
# array([[False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        ...,
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False],
#        [False, False, False, ..., False, False, False]])

# %%
plt.imshow(m)

# %%
gray = m.astype(np.uint8) * 255
edged = cv2.Canny(gray, 75, 200)
contours, _ = cv2.findContours(edged.copy(), cv2.RETR_TREE, cv2.CHAIN_APPROX_SIMPLE)
cnt = sorted(contours, key=lambda c: cv2.arcLength(c, True), reverse=True)
hull = np.intp(cv2.convexHull(np.concatenate([cnt[0], cnt[1], cnt[2], cnt[3]], axis=0)))
epsilon = 0.1 * cv2.arcLength(hull, True)
points = cv2.approxPolyDP(hull, epsilon, True)

# %%
r = context.catalog.load("express_expense")
# Out:
# [05/22/23 10:18:29] INFO     Loading data from 'express_expense' (PartitionedDataSet)...        ]8;id=629178;file:///home/zig/.pyenv/versions/3.10.8/envs/sibigrapi23/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=633979;file:///home/zig/.pyenv/versions/3.10.8/envs/sibigrapi23/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\

# %%
image = np.array(r["1002-receipt.jpg"]())

# %%
PIL.Image.fromarray(cv2.drawContours(image, [points], 0, (0, 0, 255), 2).astype('uint8'))
# Out:
# <PIL.Image.Image image mode=RGB size=750x1000>

# %%
cv2.contourArea(points)
# Out:
# 318514.0

# %%
image.shape[0] * image.shape[1]
# Out:
# 750000

# %%
318514.0 / 750000
# Out:
# 0.42468533333333336

# %%
masks = context.catalog.load("masks")
# Out:
# [05/22/23 10:13:45] INFO     Loading data from 'masks' (PartitionedDataSet)...                  ]8;id=845485;file:///home/zig/.pyenv/versions/3.10.8/envs/sibigrapi23/lib/python3.10/site-packages/kedro/io/data_catalog.py\data_catalog.py]8;;\:]8;id=159222;file:///home/zig/.pyenv/versions/3.10.8/envs/sibigrapi23/lib/python3.10/site-packages/kedro/io/data_catalog.py#343\343]8;;\

# %%
len(masks)
# Out:
# 198

# %%
masks.keys()
# Out:
# dict_keys(['1000', '1001', '1002', '1003', '1004', '1005', '1006', '1007', '1008', '1009', '1010', '1011', '1012', '1013', '1014', '1015', '1016', '1017', '1018', '1019', '1020', '1021', '1022', '1023', '1024', '1025', '1026', '1027', '1028', '1029', '1030', '1031', '1032', '1033', '1034', '1035', '1036', '1037', '1038', '1039', '1040', '1041', '1042', '1043', '1044', '1045', '1046', '1047', '1048', '1049', '1050', '1051', '1052', '1053', '1054', '1055', '1056', '1057', '1058', '1059', '1060', '1061', '1062', '1063', '1064', '1065', '1066', '1067', '1068', '1069', '1070', '1071', '1072', '1073', '1074', '1075', '1076', '1077', '1078', '1079', '1080', '1081', '1082', '1083', '1084', '1085', '1086', '1087', '1088', '1089', '1090', '1091', '1092', '1093', '1094', '1095', '1096', '1097', '1098', '1099', '1100', '1101', '1102', '1103', '1104', '1105', '1106', '1107', '1108', '1109', '1110', '1111', '1112', '1113', '1114', '1115', '1116', '1117', '1118', '1119', '1120', '1121', '1122', '11
# ...

# %%
a = masks['1000']()

# %%
a

# %%
list(a.keys())
# Out:
# ['masks', 'scores']

# %%
a['masks']
# Out:
# array([[[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False]],
#
#        [[False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         [False, False, False, ..., False, False, False],
#         ...,
#         [False, False, False, ...,  True, False, False],
# ...
